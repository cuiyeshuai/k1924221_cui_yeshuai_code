# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
type_generation_time = [
[0.8186209201812744, 0.8259987831115723, 0.8647937774658203, 0.8493928909301758],
[2.078362226486206, 2.0541062355041504, 2.0691030025482178, 2.0705549716949463],
[3.186784029006958, 3.2169649600982666, 3.252167224884033, 3.3148081302642822],
[4.441188812255859, 4.646285057067871, 4.655512094497681, 4.86228084564209],
[5.7329699993133545, 5.9265971183776855, 6.013777017593384, 6.15651893615722],
[7.045496702194214, 7.3070971965789795, 7.281564950942993, 7.524349927902222],
[8.593897104263306, 8.878905296325684, 8.982433080673218, 9.221657752990723]
]
df = pd.DataFrame(type_generation_time, columns=['None', 'Node', 'Edge', 'All'])
df.columns.name = "Specific Label"
df = df.reset_index(level=0)
df = df.melt(id_vars=['index'], var_name="Specific Label", value_name="Time")
df = df.rename(columns={"index":"Level"})
df = df.sort_values(by=['Level', "Specific Label"])
df = df.reset_index(drop=True)
plot = seaborn.barplot(x="Level", y="Time", hue="Specific Label", data=df)
plt.legend(loc='upper center', ncol=5, bbox_to_anchor=(0.5, 1.15))
plot.figure.set_size_inches(5.75, 3.25)
plt.tight_layout()
plt.savefig('type_generation_time.png')

# %%
forward_backward = [
['OpenProv',27.704782009124756, 27.00291395187378],
['CM-B',31.90118980407715, 30.681780099868774],
['CM-R',27.329636096954346, 26.31752586364746],
['CM-RS',24.038016080856323, 23.62221384048462],
['PG-D',7.749986886978149, 7.429898023605347],
['PG-T',12.425333023071289, 12.262060165405273]
]
df = pd.DataFrame(forward_backward, columns=["Dataset","Forward", "Backward"])
df = df.melt(id_vars=['Dataset'], var_name="Type", value_name="Time")
df = df.sort_values(by=['Dataset', "Type"])
plot = seaborn.barplot(x="Dataset", y="Time", hue="Type", data=df)
plt.legend(loc='upper center', ncol=5, bbox_to_anchor=(0.5, 1.15))
plot.figure.set_size_inches(5.75, 3.25)
plt.tight_layout()
plt.savefig('forward_backward.png')

# %%
json_document = [
    ["OpenProv", 94.6527030467987/6.196839094161987],
    ["CM-B", 225.32425117492676/12.835572957992554],
    ["CM-R", 244.64229083061218/14.260778903961182],
    ["CM-RS", 225.38355994224548/12.577871799468994],
    ["PG-D", 96.06562209129333/7.739271879196167],
    ["PG-T", 34.70282697677612/3.239596128463745]
]
df = pd.DataFrame(json_document, columns=["Dataset", "Doc/JSON"])
plot = seaborn.barplot(x="Dataset", order=['OpenProv', 'CM-B', 'CM-R', 'CM-RS', 'PG-D', 'PG-T'], y="Doc/JSON" ,data=df)
plot.figure.set_size_inches(5.75, 3.25)
plt.tight_layout()
plt.savefig('doc_json_ratio.png')

# %%
PGD = [[[0.6446474282822394, 57.24963998794556, 0.5945858852653709, 81.15801095962524],
[0.6444475021056495, 48.81955409049988, 0.5940803740132508, 78.79588484764099],
[0.5214375318962715, 47.43671679496765, 0.345534008829806, 77.76545190811157],
[0.5131078687177113, 45.90959119796753, 0.3504391002629231, 81.94633722305298]],
[[0.7797645522340579, 56.973838090896606, 0.6920648676729972, 81.60352396965027],
[0.7756752830006756, 50.87278985977173, 0.669184315955433, 78.34264922142029],
[0.6395871728046676, 49.33258390426636, 0.5361080210083924, 82.42859029769897],
[0.6358061153130725, 50.22596883773804, 0.5702236692769225, 79.90761184692383]],
[[0.8010455786238381, 53.56263613700867, 0.6653027644308133, 81.50905513763428],
[0.7910590798700292, 52.99131107330322, 0.6839194196965618, 81.07649421691895],
[0.6015800078001315, 49.15915012359619, 0.5447742369017559, 76.40519309043884],
[0.6274613125107538, 51.56274080276489, 0.5644095414545567, 80.57039904594421]],
[[0.7911066512024008, 66.12570691108704, 0.665832396941845, 93.14056611061096],
[0.7808750660090474, 60.46360182762146, 0.66291435999696, 94.08783316612244],
[0.6547641188014115, 54.33331084251404, 0.5437020950495245, 80.24883985519409],
[0.6433013595329694, 52.49366569519043, 0.5562854279860809, 81.61052894592285]],
[[0.773461173803722, 69.38149571418762, 0.6617217489499436, 109.10824489593506],
[0.7816720252458801, 79.10729002952576, 0.6754447667875166, 110.16834473609924],
[0.7191387996601157, 55.352975845336914, 0.6575696098405927, 85.08831477165222],
[0.7266864667978792, 54.05141496658325, 0.6225709739586778, 79.02866506576538]],
[[0.7976223064513339, 72.53595018386841, 0.6868602507400244, 111.5120849609375],
[0.7746629910173655, 71.06757402420044, 0.6463457698994586, 107.7711501121521],
[0.7647677792764849, 56.54184079170227, 0.6795446731407532, 83.92151999473572],
[0.7651733442432527, 53.55194616317749, 0.6482510330898631, 75.35268568992615]],
[[0.7904601259130339, 90.04625296592712, 0.6969276359029785, 121.18484234809875],
[0.7833940033482877, 81.2672061920166, 0.7065930791538519, 116.90145516395569],
[0.7610900174337754, 60.64286684989929, 0.6333901425787585, 87.29447293281555],
[0.7645133990269182, 59.47990298271179, 0.6650280597505058, 85.32249999046326]]]
for x in range(len(PGD)):
    for y in range(len(PGD[x])):
        PGD[x][y] = [PGD[x][y][0],PGD[x][y][2]]
df = pd.DataFrame(PGD, columns=["All", "Node", "Edge", "None"])
df = df.reset_index(level=0)
df.columns.name = "Type"
df = df.melt(id_vars="index", value_vars=["All", "Node", "Edge", "None"], var_name="Type", value_name="Accuracy")
df = df.rename(columns={"index":"Level"})
x = pd.DataFrame(df['Accuracy'].values.tolist(), columns=["rf","lr"])
df = df.join(x)
df.drop(columns=["Accuracy"], inplace=True)
df = df.melt(id_vars=["Level","Type"], value_vars=["rf","lr"], var_name="Model", value_name="Accuracy")
df = df.sort_values(by=["Level","Type","Model"])
plot = seaborn.relplot(x="Level", y="Accuracy", hue=df[["Model","Type"]].apply(tuple, axis=1), data=df, kind="line")
# hue parameter comes from user dlukes in https://stackoverflow.com/a/70627358/17611672
plot.figure.savefig("PG-D.png")

# %%
PGT = [
[[0.8471692902236295, 47.56994581222534, 0.8367551704566494, 70.75727701187134],
[0.851758723760368, 50.22700381278992, 0.8365680079707086, 85.0824990272522],
[0.7001176730019683, 40.609861850738525, 0.6335385505890501, 67.6545159816742],
[0.7070628781461022, 40.13599181175232, 0.6406765733941848, 67.16774201393127]],
[[0.8569907601002901, 52.84951710700989, 0.8381819106232471, 80.70960998535156],
[0.848727221224741, 44.16155481338501, 0.8441542594642792, 75.34181213378906],
[0.7188892306249753, 44.05465292930603, 0.6637900843862388, 69.56083512306213],
[0.7063942845987331, 42.51907396316528, 0.6516510842557551, 71.04817986488342]],
[[0.8436803518314195, 43.56984996795654, 0.8436611220732074, 76.42151713371277],
[0.8495146697049268, 43.66143202781677, 0.837543400548464, 76.93075203895569],
[0.698785153736515, 51.86244487762451, 0.6266891870335038, 74.13770818710327],
[0.6961430556625854, 42.85224914550781, 0.6245259364948776, 72.3737940788269]],
[[0.8515280340521568, 45.84507489204407, 0.8428015404489106, 78.48816585540771],
[0.8480083998586323, 45.15172505378723, 0.8359138634073323, 81.34390497207642],
[0.6793632318212143, 47.17842197418213, 0.6333570400449383, 73.85026717185974],
[0.6733725650591312, 46.39320778846741, 0.6414361032193423, 71.53775787353516]],
[[0.8742621849862144, 48.4368462562561, 0.8413715421719025, 83.15014100074768],
[0.8461571635028996, 48.07825016975403, 0.8412949528342373, 83.9346010684967],
[0.6807270587900885, 46.79470086097717, 0.6599268910941987, 74.86096787452698],
[0.6883738143469199, 44.897780895233154, 0.6647767934203135, 71.58296799659729]],
[[0.8683561603384164, 52.111504793167114, 0.8394377882975457, 84.48389101028442],
[0.8536708693523883, 50.65577983856201, 0.8214162783895629, 91.3149790763855],
[0.7081067569434496, 49.774534940719604, 0.6567936019717654, 72.52278518676758],
[0.6870623864604279, 54.7787389755249, 0.6640404170746784, 76.38559603691101]],
[[0.8516161657691393, 51.32950401306152, 0.8463478202047631, 92.90205097198486],
[0.8525226736188147, 52.486517906188965, 0.8417355806198892, 88.99407196044922],
[0.6908616550274188, 46.651371002197266, 0.6445834552513445, 73.39898705482483],
[0.6981846183263147, 47.24341297149658, 0.6443794174575915, 72.84900903701782]]
]
for x in range(len(PGT)):
    for y in range(len(PGT[x])):
        PGT[x][y] = [PGT[x][y][0],PGT[x][y][2]]
df = pd.DataFrame(PGT, columns=["All", "Node", "Edge", "None"])
df = df.reset_index(level=0)
df.columns.name = "Type"
df = df.melt(id_vars="index", value_vars=["All", "Node", "Edge", "None"], var_name="Type", value_name="Accuracy")
df = df.rename(columns={"index":"Level"})
x = pd.DataFrame(df['Accuracy'].values.tolist(), columns=["rf","lr"])
df = df.join(x)
df.drop(columns=["Accuracy"], inplace=True)
df = df.melt(id_vars=["Level","Type"], value_vars=["rf","lr"], var_name="Model", value_name="Accuracy")
df = df.sort_values(by=["Level","Type","Model"])
plot = seaborn.relplot(x="Level", y="Accuracy", hue=df[["Model","Type"]].apply(tuple, axis=1), data=df, kind="line")
# hue parameter comes from user dlukes in https://stackoverflow.com/a/70627358/17611672
plot.figure.savefig("PG-T.png")

# %%
CMB = [
[[0.8652532890991299, 736.6236763000488, 0.8740116222485322, 55.618738889694214, 0.9053529538218159, 105.63258004188538, 0.8622645593236089, 58.529199838638306],
[0.8638995688650141, 950.2360560894012, 0.8743350830303709, 54.29150915145874, 0.9046307956837059, 105.0008499622345, 0.8631280381581492, 61.70804691314697],
[0.8060522437084372, 893.5546870231628, 0.8912659005534729, 54.776816844940186, 0.8912659005534729, 105.6533031463623, 0.8050254937343911, 50.013916969299316],
[0.8069637610418506, 580.8069388866425, 0.8898238715800166, 57.31666398048401, 0.8899234235354407, 105.10406494140625, 0.7884525248294575, 51.79647421836853]],
[[0.8628911146859255, 1332.374585866928, 0.8737099302034765, 63.668235778808594, 0.9058102717002362, 111.80848002433777, 0.8613495761537195, 70.03169798851013],
[0.8631928620192226, 865.7122087478638, 0.8763662960557458, 59.1291069984436, 0.897354624800706, 107.4407651424408, 0.8631928620192226, 70.41668486595154],
[0.865615399951079, 1037.8139567375183, 0.9002193513561121, 56.66321396827698, 0.9018683018554444, 107.36530494689941, 0.865615399951079, 61.595361948013306],
[0.7899661496022903, 718.9265940189362, 0.895417919258098, 56.13427376747131, 0.8951951479633453, 105.91888380050659, 0.8052924018740784, 50.41953921318054]],
[[0.8635594467424557, 1059.2592689990997, 0.8741634818221009, 60.30794286727905, 0.9030338953709159, 114.5575520992279, 0.863565236978013, 74.2204520702362],
[0.8645542751002175, 859.4295828342438, 0.8896687482766189, 57.37589907646179, 0.9032118705012221, 110.13458800315857, 0.8629958002247585, 71.7212507724762],
[0.8612903499887673, 1239.8756170272827, 0.8729973540766152, 57.689146995544434, 0.9016175247963357, 109.7496120929718, 0.8599075857164274, 71.5066750049591],
[0.7909470288177967, 490.0810799598694, 0.9058281949693174, 65.57796382904053, 0.9060577769273105, 122.08141493797302, 0.7707355206837148, 57.37899708747864]],
[[0.862669340147165, 1134.7308769226074, 0.8732647619389827, 72.58556318283081, 0.8994800558761369, 126.75517416000366, 0.8626548302078565, 83.158931016922],
[0.8636750699764596, 1112.180652141571, 0.8721573898767797, 61.88864016532898, 0.9086236662522603, 116.30665183067322, 0.8609460993452662, 76.15329194068909],
[0.8615388962510513, 987.6058189868927, 0.8733344017073563, 63.70511794090271, 0.8982207853209214, 117.04240679740906, 0.8615388962510513, 75.7406702041626],
[0.8627435107985201, 899.7892742156982, 0.9040377300286994, 58.58063197135925, 0.9041505968458551, 111.381511926651, 0.8625198888423993, 73.134437084198]],
[[0.861896113108268, 902.6444306373596, 0.872403919701833, 85.50813508033752, 0.8989753457618603, 131.36096096038818, 0.8610066427422007, 94.53995490074158],
[0.8622664509292408, 862.3756392002106, 0.8739653216634912, 73.1213800907135, 0.8961249102114771, 131.21853113174438, 0.8612634042650669, 86.59579420089722],
[0.8636728332127789, 1033.082675933838, 0.872732402339302, 78.30309510231018, 0.9042193009801317, 139.08438920974731, 0.8635586779616373, 90.15353608131409],
[0.8616277928667623, 1007.8683898448944, 0.8744718769172517, 67.6689441204071, 0.8999934095229277, 128.80187582969666, 0.8618550913590808, 85.47555422782898]],
[[0.8649813595666334, 836.0637362003326, 0.8759175845990955, 77.62256383895874, 0.9062597460693197, 134.87046813964844, 0.8643282478677773, 84.92657399177551],
[0.8629461537403397, 928.6029138565063, 0.8746182054375164, 65.11255311965942, 0.9020259012486658, 120.84702610969543, 0.8628501702675534, 77.23831176757812],
[0.8646402481607051, 884.1346259117126, 0.8712404211446169, 82.44192504882812, 0.8997047243085217, 145.4601058959961, 0.8644103388188971, 93.22326683998108],
[0.8636501413619053, 1099.2682831287384, 0.8991022254232264, 62.4998939037323, 0.9056829486051361, 115.65252566337585, 0.8636678512268188, 75.62750792503357]],
[[0.8632615288071771, 966.1060039997101, 0.8727976259006697, 99.40834712982178, 0.8971203026822739, 147.62185287475586, 0.8608018419941448, 89.00813007354736],
[0.8628895218502156, 857.3228280544281, 0.8735693641389837, 71.46770596504211, 0.9041994698033049, 126.29849195480347, 0.8621992661320274, 82.28130316734314],
[0.86134126170159, 934.5860950946808, 0.8701907749979075, 75.7814450263977, 0.9019531223576225, 133.30513286590576, 0.8612294048783237, 83.3623559474945],
[0.8609855737460346, 878.6625800132751, 0.8757688825454292, 64.01384496688843, 0.9049827308380191, 118.21036791801453, 0.8609866485107969, 77.69967889785767]]
]
for x in range(len(CMB)):
    for y in range(len(CMB[x])):
        CMB[x][y] = [CMB[x][y][0],CMB[x][y][2],CMB[x][y][4],CMB[x][y][6]]
df = pd.DataFrame(CMB, columns=["All", "Node", "Edge", "None"])
df = df.reset_index(level=0)
df.columns.name = "Type"
df = df.melt(id_vars="index", value_vars=["All", "Node", "Edge", "None"], var_name="Type", value_name="Accuracy")
df = df.rename(columns={"index":"Level"})
x = pd.DataFrame(df['Accuracy'].values.tolist(), columns=["svm","rf","gbt","lr"])
df = df.join(x)
df.drop(columns=["Accuracy"], inplace=True)
df = df.melt(id_vars=["Level","Type"], value_vars=["svm","rf","gbt","lr"], var_name="Model", value_name="Accuracy")
df = df.sort_values(by=["Level","Type","Model"])
df = df[df["Type"].isin(["All","None"])]
plot = seaborn.relplot(x="Level", y="Accuracy", hue=df[["Model","Type"]].apply(tuple, axis=1), data=df, kind="line")
# hue parameter comes from user dlukes in https://stackoverflow.com/a/70627358/17611672
plot.figure.savefig("CMB_model.png")

# %%
df = pd.DataFrame(CMB, columns=["All", "Node", "Edge", "None"])
df = df.reset_index(level=0)
df.columns.name = "Type"
df = df.melt(id_vars="index", value_vars=["All", "Node", "Edge", "None"], var_name="Type", value_name="Accuracy")
df = df.rename(columns={"index":"Level"})
x = pd.DataFrame(df['Accuracy'].values.tolist(), columns=["svm","rf","gbt","lr"])
df = df.join(x)
df.drop(columns=["Accuracy"], inplace=True)
df = df.melt(id_vars=["Level","Type"], value_vars=["svm","rf","gbt","lr"], var_name="Model", value_name="Accuracy")
df = df.sort_values(by=["Level","Type","Model"])
df = df[df["Model"].isin(["gbt","svm"])]
plot = seaborn.relplot(x="Level", y="Accuracy", hue=df[["Model","Type"]].apply(tuple, axis=1), data=df, kind="line")
plot.figure.savefig("CMB_config.png")

# %%
PG_T_E = [
[[0.8422238365535005, 47.18777298927307, 0.8213572042163005, 75.04922819137573],
[0.8426470446588159, 45.701658964157104, 0.8361862481243737, 75.36836194992065],
[0.6879253145869674, 46.05750894546509, 0.6357315773978953, 74.6230537891388],
[0.7022657276695079, 47.16085505485535, 0.6263199331815572, 78.5290641784668]],
[[0.8440590370047563, 45.331665992736816, 0.8425713017694508, 81.46619129180908],
[0.8491044020105918, 46.68584871292114, 0.8356814673810209, 82.64821195602417],
[0.7730513072284407, 46.762831926345825, 0.664494380158005, 79.27463889122009],
[0.6759658897154948, 45.90067410469055, 0.6372639124958321, 76.18302297592163]],
[[0.8445757228198112, 49.432079792022705, 0.8374326868423216, 88.09130692481995],
[0.842662779941957, 46.87677597999573, 0.837515629709511, 84.0093150138855],
[0.7671880664885741, 47.19741082191467, 0.621330324342653, 84.20457887649536],
[0.6875529644686487, 48.41818189620972, 0.6345091549114167, 72.16812992095947]],
[[0.8444879827592592, 52.53626012802124, 0.8245835740256072, 84.68880605697632],
[0.8488865934697063, 51.60175585746765, 0.8425723004914389, 82.58537888526917],
[0.7550777203341816, 52.099071979522705, 0.6412344941004995, 84.38473200798035],
[0.6768480786961436, 48.24983501434326, 0.6348874523148015, 79.7724928855896]],
[[0.8502591882387397, 57.406413078308105, 0.8440180573930388, 95.23328995704651],
[0.8556185159049021, 51.59000778198242, 0.8364593297167238, 93.98765683174133],
[0.7622062654422562, 51.540775299072266, 0.6428116456034415, 95.81100606918335],
[0.6831450001831211, 56.85874009132385, 0.6306787990517823, 82.3931610584259]],
[[0.8449650376930183, 66.38666081428528, 0.839291465578545, 108.78999590873718],
[0.8424482388172799, 50.40796875953674, 0.8382747679629147, 95.8766610622406],
[0.7683871345391092, 60.208290100097656, 0.6882780041718511, 93.59039783477783],
[0.6798123795964093, 47.79396295547485, 0.6367935013312953, 80.40386509895325]],
[[0.8387475021217361, 75.75271677970886, 0.8319318381286113, 111.72085809707642],
[0.8472084770160113, 59.21044397354126, 0.8321859885231414, 97.00028991699219],
[0.7699933293790127, 60.01942825317383, 0.7056701250002635, 100.50257086753845],
[0.6875321729920129, 50.868452072143555, 0.6294241954671295, 66.69196701049805]]
]
for x in range(len(PG_T_E)):
    for y in range(len(PG_T_E[x])):
        PG_T_E[x][y] = [PG_T_E[x][y][0],PG_T_E[x][y][2]]
df = pd.DataFrame(PG_T_E, columns=["All", "Node", "Edge", "None"])
df = df.reset_index(level=0)
df.columns.name = "Type"
df = df.melt(id_vars="index", value_vars=["All", "Node", "Edge", "None"], var_name="Type", value_name="Accuracy")
df = df.rename(columns={"index":"Level"})
x = pd.DataFrame(df['Accuracy'].values.tolist(), columns=["rf","lr"])
df = df.join(x)
df.drop(columns=["Accuracy"], inplace=True)
df = df.melt(id_vars=["Level","Type"], value_vars=["rf","lr"], var_name="Model", value_name="Accuracy")
df = df.sort_values(by=["Level","Type","Model"])
plot = seaborn.relplot(x="Level", y="Accuracy", hue=df[["Model","Type"]].apply(tuple, axis=1), data=df, kind="line")
# hue parameter comes from user dlukes in https://stackoverflow.com/a/70627358/17611672
plot.figure.savefig("PG-T-E.png")

# %%
PG_D_E = [
[[0.6449444884495315, 57.371054887771606, 0.5301109478961813, 81.8953161239624],
[0.6545820897992818, 50.70252799987793, 0.5699511247671254, 76.58873701095581],
[0.5125567700312443, 49.52751898765564, 0.30129367631645965, 84.36449480056763],
[0.5176145925754498, 50.17137885093689, 0.30572114029066055, 87.89389204978943]],
[[0.7887230496696964, 54.596543073654175, 0.6875587345339373, 84.4583113193512],
[0.789210608884773, 52.221404790878296, 0.6951318547272313, 88.0117199420929],
[0.6430380447856545, 48.2794668674469, 0.5620138236295672, 87.87141990661621],
[0.6174227518640627, 51.249918937683105, 0.5528953916241538, 87.35380911827087]],
[[0.8040177612620775, 57.81932473182678, 0.7128190568178495, 92.60704731941223],
[0.7886305446036583, 55.16765904426575, 0.6788033974522938, 87.79673290252686],
[0.7219672820179704, 54.29321765899658, 0.5962406336677927, 85.85849499702454],
[0.6393657483783829, 53.95083689689636, 0.555989705884594, 82.41319012641907]],
[[0.7768359352450691, 67.82535290718079, 0.7207062944537378, 105.24671006202698],
[0.8010050067820619, 64.34696412086487, 0.6976542502253664, 101.74632501602173],
[0.7169593237215861, 59.30987906455994, 0.5964173721885775, 93.50826907157898],
[0.6588588504055505, 55.04368615150452, 0.5663644908924684, 91.3087842464447]],
[[0.7897929206382914, 82.7786591053009, 0.6935635170054294, 124.68696618080139],
[0.7895233729961815, 75.31504678726196, 0.6500211867574923, 96.56831932067871],
[0.7494790812883737, 55.00334882736206, 0.6286073463202793, 83.72509002685547],
[0.7280545141415282, 49.597609996795654, 0.6147345369787836, 75.55785918235779]],
[[0.7834769138316943, 94.32616090774536, 0.6989156201870095, 146.0569248199463],
[0.7908801270705385, 67.59601879119873, 0.6736927147685178, 110.31567168235779],
[0.7686757822904263, 69.44216012954712, 0.6211484251597559, 113.42385411262512],
[0.7613088422448986, 60.747292280197144, 0.6768144648028708, 89.53821182250977]],
[[0.757940390408713, 137.35613489151, 0.693376280117845, 176.68336582183838],
[0.7820645609262425, 86.38179993629456, 0.6963994979231574, 127.45395183563232],
[0.7607968121195164, 86.74198389053345, 0.6169173449747385, 117.93370294570923],
[0.7340957259863311, 65.19594383239746, 0.6694195208650277, 95.27025294303894]]
]
for x in range(len(PG_D_E)):
    for y in range(len(PG_D_E[x])):
        PG_D_E[x][y] = [PG_D_E[x][y][0],PG_D_E[x][y][2]]
df = pd.DataFrame(PG_D_E, columns=["All", "Node", "Edge", "None"])
df = df.reset_index(level=0)
df.columns.name = "Type"
df = df.melt(id_vars="index", value_vars=["All", "Node", "Edge", "None"], var_name="Type", value_name="Accuracy")
df = df.rename(columns={"index":"Level"})
x = pd.DataFrame(df['Accuracy'].values.tolist(), columns=["rf","lr"])
df = df.join(x)
df.drop(columns=["Accuracy"], inplace=True)
df = df.melt(id_vars=["Level","Type"], value_vars=["rf","lr"], var_name="Model", value_name="Accuracy")
df = df.sort_values(by=["Level","Type","Model"])
plot = seaborn.relplot(x="Level", y="Accuracy", hue=df[["Model","Type"]].apply(tuple, axis=1), data=df, kind="line")
# hue parameter comes from user dlukes in https://stackoverflow.com/a/70627358/17611672
plot.figure.savefig("PG-D-E.png")
